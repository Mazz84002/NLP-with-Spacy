# %% [markdown]
# # SPANCAT

# %%
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
spancat = nlp.add_pipe("spancat")


from spacy.tokens import Doc
from spacy.training import Example

from spacy.vocab import Vocab
vocab = Vocab(strings=["Appy", "some", "sunscreen"])

def get_examples():
    predicted = Doc(vocab, words=["Apply", "some", "sunscreen"])
    token_ref = ["Apply", "some", "sun", "screen"]
    tags_ref = ["VERB", "DET", "NOUN", "NOUN"]
    example = Example.from_dict(predicted, {"words": token_ref, "tags": tags_ref})
    yield example

spancat.add_label("SPANCAT")
spancat.initialize(get_examples, nlp=nlp)

text = "South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix."
doc = nlp(text)

# %% [markdown]
# ### Initialise `doc.spans["sc"]`

# %%
from spacy.tokens import Span
doc.spans["sc"] = []

# %% [markdown]
# ### Recursive Procedure to extract non-duplicate spans

# %%
# pass after removing colons
def find_spans(doc):
    for i in range(0, len(doc)-1):
        print("i=", i)
        for j in range(i+1, len(doc)):
            print("j=", j)
            tdoc = nlp(doc[i:j].text)
            print("tdoc = ", tdoc)
            for ent in tdoc.ents:
                print("ent=",  ent.text)
                label = ent.label_
                s = ent.start + i
                t = ent.end + i
                print("s=", s)
                print("t=", t)
                print(ent.text,"=" ,label)
                span = Span(doc, s, t, label)
                print("span = ",span)
                if span not in doc.spans["sc"]:
                    doc.spans["sc"].append(span)
                    print("added")
                    print("doc.spans=", doc.spans["sc"])
            print("---------------------")

# %%
find_spans(doc)
# Out:
# i= 0
# j= 1
# tdoc =  South
# ---------------------
# j= 2
# tdoc =  South Korea
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# added
# doc.spans= [South Korea]
# ---------------------
# j= 3
# tdoc =  South Korea along
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ---------------------
# j= 4
# tdoc =  South Korea along with
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ---------------------
# j= 5
# tdoc =  South Korea along with Taiwan
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# added
# doc.spans= [South Korea, Taiwan]
# ---------------------
# j= 6
# tdoc =  South Korea along with Taiwan and
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 7
# tdoc =  South Korea along with Taiwan and Japan
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# added
# doc.spans= [South Korea, Taiwan, Japan]
# ---------------------
# j= 8
# tdoc =  South Korea along with Taiwan and Japan is
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  South Korea along with Taiwan and Japan is a
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  South Korea along with Taiwan and Japan is a leading
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# added
# doc.spans= [South Korea, Taiwan, Japan, 4]
# ---------------------
# j= 15
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung]
# ---------------------
# j= 22
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics]
# ---------------------
# j= 23
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics, SK]
# ---------------------
# j= 25
# tdoc =  South Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= South Korea
# s= 0
# t= 2
# South Korea = GPE
# span =  South Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics, SK, SK Hynix]
# ---------------------
# i= 1
# j= 2
# tdoc =  Korea
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics, SK, SK Hynix, Korea]
# ---------------------
# j= 3
# tdoc =  Korea along
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ---------------------
# j= 4
# tdoc =  Korea along with
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ---------------------
# j= 5
# tdoc =  Korea along with Taiwan
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 6
# tdoc =  Korea along with Taiwan and
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 7
# tdoc =  Korea along with Taiwan and Japan
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  Korea along with Taiwan and Japan is
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  Korea along with Taiwan and Japan is a
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  Korea along with Taiwan and Japan is a leading
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  Korea along with Taiwan and Japan is a leading innovator
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  Korea along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Korea
# s= 1
# t= 2
# Korea = GPE
# span =  Korea
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 2
# j= 3
# tdoc =  along
# ---------------------
# j= 4
# tdoc =  along with
# ---------------------
# j= 5
# tdoc =  along with Taiwan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 6
# tdoc =  along with Taiwan and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 7
# tdoc =  along with Taiwan and Japan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  along with Taiwan and Japan is
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  along with Taiwan and Japan is a
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  along with Taiwan and Japan is a leading
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  along with Taiwan and Japan is a leading innovator
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  along with Taiwan and Japan is a leading innovator in
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  along with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 3
# j= 4
# tdoc =  with
# ---------------------
# j= 5
# tdoc =  with Taiwan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 6
# tdoc =  with Taiwan and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 7
# tdoc =  with Taiwan and Japan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  with Taiwan and Japan is
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  with Taiwan and Japan is a
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  with Taiwan and Japan is a leading
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  with Taiwan and Japan is a leading innovator
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  with Taiwan and Japan is a leading innovator in
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  with Taiwan and Japan is a leading innovator in advanced
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  with Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 4
# j= 5
# tdoc =  Taiwan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 6
# tdoc =  Taiwan and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ---------------------
# j= 7
# tdoc =  Taiwan and Japan
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  Taiwan and Japan is
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  Taiwan and Japan is a
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  Taiwan and Japan is a leading
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  Taiwan and Japan is a leading innovator
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  Taiwan and Japan is a leading innovator in
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  Taiwan and Japan is a leading innovator in advanced
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  Taiwan and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Taiwan
# s= 4
# t= 5
# Taiwan = GPE
# span =  Taiwan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 5
# j= 6
# tdoc =  and
# ---------------------
# j= 7
# tdoc =  and Japan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  and Japan is
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  and Japan is a
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  and Japan is a leading
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  and Japan is a leading innovator
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  and Japan is a leading innovator in
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  and Japan is a leading innovator in advanced
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  and Japan is a leading innovator in advanced 4
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  and Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 6
# j= 7
# tdoc =  Japan
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 8
# tdoc =  Japan is
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 9
# tdoc =  Japan is a
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 10
# tdoc =  Japan is a leading
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 11
# tdoc =  Japan is a leading innovator
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 12
# tdoc =  Japan is a leading innovator in
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 13
# tdoc =  Japan is a leading innovator in advanced
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ---------------------
# j= 14
# tdoc =  Japan is a leading innovator in advanced 4
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  Japan is a leading innovator in advanced 4 nanometer
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  Japan is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Japan
# s= 6
# t= 7
# Japan = GPE
# span =  Japan
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 7
# j= 8
# tdoc =  is
# ---------------------
# j= 9
# tdoc =  is a
# ---------------------
# j= 10
# tdoc =  is a leading
# ---------------------
# j= 11
# tdoc =  is a leading innovator
# ---------------------
# j= 12
# tdoc =  is a leading innovator in
# ---------------------
# j= 13
# tdoc =  is a leading innovator in advanced
# ---------------------
# j= 14
# tdoc =  is a leading innovator in advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  is a leading innovator in advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  is a leading innovator in advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  is a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 8
# j= 9
# tdoc =  a
# ---------------------
# j= 10
# tdoc =  a leading
# ---------------------
# j= 11
# tdoc =  a leading innovator
# ---------------------
# j= 12
# tdoc =  a leading innovator in
# ---------------------
# j= 13
# tdoc =  a leading innovator in advanced
# ---------------------
# j= 14
# tdoc =  a leading innovator in advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  a leading innovator in advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  a leading innovator in advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  a leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 9
# j= 10
# tdoc =  leading
# ---------------------
# j= 11
# tdoc =  leading innovator
# ---------------------
# j= 12
# tdoc =  leading innovator in
# ---------------------
# j= 13
# tdoc =  leading innovator in advanced
# ---------------------
# j= 14
# tdoc =  leading innovator in advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  leading innovator in advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  leading innovator in advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  leading innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 10
# j= 11
# tdoc =  innovator
# ---------------------
# j= 12
# tdoc =  innovator in
# ---------------------
# j= 13
# tdoc =  innovator in advanced
# ---------------------
# j= 14
# tdoc =  innovator in advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  innovator in advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  innovator in advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  innovator in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 11
# j= 12
# tdoc =  in
# ---------------------
# j= 13
# tdoc =  in advanced
# ---------------------
# j= 14
# tdoc =  in advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  in advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  in advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  in advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  in advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  in advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 12
# j= 13
# tdoc =  advanced
# ---------------------
# j= 14
# tdoc =  advanced 4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  advanced 4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  advanced 4 nanometer ARM
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 17
# tdoc =  advanced 4 nanometer ARM semiconductors
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 18
# tdoc =  advanced 4 nanometer ARM semiconductors with
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 19
# tdoc =  advanced 4 nanometer ARM semiconductors with companies
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 20
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 21
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like Samsung
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  advanced 4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 13
# j= 14
# tdoc =  4
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 15
# tdoc =  4 nanometer
# ent= 4
# s= 13
# t= 14
# 4 = CARDINAL
# span =  4
# ---------------------
# j= 16
# tdoc =  4 nanometer ARM
# ---------------------
# j= 17
# tdoc =  4 nanometer ARM semiconductors
# ---------------------
# j= 18
# tdoc =  4 nanometer ARM semiconductors with
# ---------------------
# j= 19
# tdoc =  4 nanometer ARM semiconductors with companies
# ---------------------
# j= 20
# tdoc =  4 nanometer ARM semiconductors with companies like
# ---------------------
# j= 21
# tdoc =  4 nanometer ARM semiconductors with companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  4 nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  4 nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  4 nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  4 nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 14
# j= 15
# tdoc =  nanometer
# ---------------------
# j= 16
# tdoc =  nanometer ARM
# ---------------------
# j= 17
# tdoc =  nanometer ARM semiconductors
# ---------------------
# j= 18
# tdoc =  nanometer ARM semiconductors with
# ---------------------
# j= 19
# tdoc =  nanometer ARM semiconductors with companies
# ---------------------
# j= 20
# tdoc =  nanometer ARM semiconductors with companies like
# ---------------------
# j= 21
# tdoc =  nanometer ARM semiconductors with companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  nanometer ARM semiconductors with companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  nanometer ARM semiconductors with companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  nanometer ARM semiconductors with companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  nanometer ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 15
# j= 16
# tdoc =  ARM
# ---------------------
# j= 17
# tdoc =  ARM semiconductors
# ---------------------
# j= 18
# tdoc =  ARM semiconductors with
# ---------------------
# j= 19
# tdoc =  ARM semiconductors with companies
# ---------------------
# j= 20
# tdoc =  ARM semiconductors with companies like
# ---------------------
# j= 21
# tdoc =  ARM semiconductors with companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  ARM semiconductors with companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  ARM semiconductors with companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  ARM semiconductors with companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  ARM semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 16
# j= 17
# tdoc =  semiconductors
# ---------------------
# j= 18
# tdoc =  semiconductors with
# ---------------------
# j= 19
# tdoc =  semiconductors with companies
# ---------------------
# j= 20
# tdoc =  semiconductors with companies like
# ---------------------
# j= 21
# tdoc =  semiconductors with companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  semiconductors with companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  semiconductors with companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  semiconductors with companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  semiconductors with companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 17
# j= 18
# tdoc =  with
# ---------------------
# j= 19
# tdoc =  with companies
# ---------------------
# j= 20
# tdoc =  with companies like
# ---------------------
# j= 21
# tdoc =  with companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  with companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  with companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  with companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  with companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 18
# j= 19
# tdoc =  companies
# ---------------------
# j= 20
# tdoc =  companies like
# ---------------------
# j= 21
# tdoc =  companies like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  companies like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  companies like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  companies like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  companies like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 19
# j= 20
# tdoc =  like
# ---------------------
# j= 21
# tdoc =  like Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  like Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  like Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  like Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  like Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 20
# j= 21
# tdoc =  Samsung
# ent= Samsung
# s= 20
# t= 21
# Samsung = ORG
# span =  Samsung
# ---------------------
# j= 22
# tdoc =  Samsung Electronics
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 23
# tdoc =  Samsung Electronics and
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ---------------------
# j= 24
# tdoc =  Samsung Electronics and SK
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  Samsung Electronics and SK Hynix
# ent= Samsung Electronics
# s= 20
# t= 22
# Samsung Electronics = ORG
# span =  Samsung Electronics
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 21
# j= 22
# tdoc =  Electronics
# ---------------------
# j= 23
# tdoc =  Electronics and
# ---------------------
# j= 24
# tdoc =  Electronics and SK
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  Electronics and SK Hynix
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 22
# j= 23
# tdoc =  and
# ---------------------
# j= 24
# tdoc =  and SK
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  and SK Hynix
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 23
# j= 24
# tdoc =  SK
# ent= SK
# s= 23
# t= 24
# SK = ORG
# span =  SK
# ---------------------
# j= 25
# tdoc =  SK Hynix
# ent= SK Hynix
# s= 23
# t= 25
# SK Hynix = PERSON
# span =  SK Hynix
# ---------------------
# i= 24
# j= 25
# tdoc =  Hynix
# ent= Hynix
# s= 24
# t= 25
# Hynix = ORG
# span =  Hynix
# added
# doc.spans= [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics, SK, SK Hynix, Korea, Hynix]
# ---------------------

# %%
print(doc.spans["sc"])
# Out:
# [South Korea, Taiwan, Japan, 4, Samsung, Samsung Electronics, SK, SK Hynix, Korea, Hynix]

# %%
displacy.serve(doc, style="span")
# Out:
# /Users/mazz/opt/anaconda3/envs/NLP_env/lib/python3.9/site-packages/spacy/displacy/__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     South
#
# <span style="background: #feca74; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #feca74; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #feca74; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         GPE
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Korea
#
# <span style="background: #feca74; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #feca74; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #feca74; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #feca74; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         GPE
#     </span>
# </span>
#
#
# </span>
# along with
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Taiwan
#
# <span style="background: #feca74; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #feca74; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #feca74; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         GPE
#     </span>
# </span>
#
#
# </span>
# and
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Japan
#
# <span style="background: #feca74; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #feca74; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #feca74; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         GPE
#     </span>
# </span>
#
#
# </span>
# is a leading innovator in advanced
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     4
#
# <span style="background: #e4e7d2; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #e4e7d2; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #e4e7d2; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         CARDINAL
#     </span>
# </span>
#
#
# </span>
# nanometer ARM semiconductors with companies like
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Samsung
#
# <span style="background: #7aecec; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #7aecec; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #7aecec; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #7aecec; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ORG
#     </span>
# </span>
#
#
# <span style="background: #7aecec; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #7aecec; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ORG
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Electronics
#
# <span style="background: #7aecec; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# and
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     SK
#
# <span style="background: #7aecec; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #aa9cfc; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #7aecec; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #7aecec; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ORG
#     </span>
# </span>
#
#
# <span style="background: #aa9cfc; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #aa9cfc; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         PERSON
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative;">
#     Hynix
#
# <span style="background: #aa9cfc; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #7aecec; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #7aecec; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #7aecec; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ORG
#     </span>
# </span>
#
#
# </span>
# . </div>
# </figure>
# </body>
# </html></span>
# Using the 'span' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Roungh Work

# %%
for token in doc:
    print(token)

# %%
for token in doc:
    print(token.ent_type_)

# %%
for token in doc:
    print(token.ent_type)

# %%
print(doc[0:3])

# %%
tdoc = doc[3:6]
print(tdoc)

# %%
tdoc1 = nlp(doc[2+1:5].text)
tdoc2 = doc[2:5-1]
print(tdoc1)
print(tdoc2)

# %%
for ent in tdoc1.ents:
    print(ent)
    word_start1 = ent.start
    word_end1 = ent.end
    print(word_start1)

    index_start1 = ent.start_char
    index_end1 = ent.end_char
    print(index_start1)

    label1 = ent.label_

    span = Span(doc, word_start1+word_start + 1, word_end1+word_start + 1, label1)
    doc.spans["sc"].append(span)

for ent in tdoc2.ents:
    print(ent)

# %%
print(doc.spans["sc"])

# %%
for span in doc.spans["sc"]:
    print(len(span))

# %%
displacy.serve(doc, style="span")

# %%
doc = nlp("Bank of")
for ent in doc.ents:
    print(ent.text)
